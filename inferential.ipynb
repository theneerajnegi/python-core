# %%
import numpy as np 
import pandas as pd 
import scipy.stats 
import seaborn as sns
import statsmodels
from statsmodels.stats.weightstats import ztest as zt

# %%
help(zt)
# Out:
# Help on function ztest in module statsmodels.stats.weightstats:
#
# ztest(x1, x2=None, value=0, alternative='two-sided', usevar='pooled', ddof=1.0)
#     test for mean based on normal distribution, one or two samples
#
#     In the case of two samples, the samples are assumed to be independent.
#
#     Parameters
#     ----------
#     x1 : array_like, 1-D or 2-D
#         first of the two independent samples
#     x2 : array_like, 1-D or 2-D
#         second of the two independent samples
#     value : float
#         In the one sample case, value is the mean of x1 under the Null
#         hypothesis.
#         In the two sample case, value is the difference between mean of x1 and
#         mean of x2 under the Null hypothesis. The test statistic is
#         `x1_mean - x2_mean - value`.
#     alternative : str
#         The alternative hypothesis, H1, has to be one of the following
#
#            'two-sided': H1: difference in means not equal to value (default)
# ...

# %%
df=pd.read_csv("C:\\Users\\Neeraj\\Desktop\\bloodpressure.csv")
df
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
x1=df["bp_before"][0:40]
x2=df["bp_after"][0:40]

# %%
t_val,pval=scipy.stats.ttest_rel(x1,x2)
print(pval)
print(t_val)
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.18971431308295203
# 1.3347010727377813
# accept null hypothesis

# %%
df1=pd.DataFrame({"height":[170,180,120,160,150],"weight":[85,95,60,80,75]})
df1
# Out:
#    height  weight
# 0     170      85
# 1     180      95
# 2     120      60
# 3     160      80
# 4     150      75

# %% [markdown]
# # CHI SQUARE TEST

# %% [markdown]
# # annova

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(["sex"])["smoker"].value_counts()
# Out:
# sex
# Male    No     97
#         Yes    60
# Female  No     54
#         Yes    33
# Name: smoker, dtype: int64

# %%
a=pd.crosstab(df["sex"],df["smoker"])
a
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
va=scipy.stats.chi2_contingency(a)
va
# Out:
# (0.0,
#  1.0,
#  1,
#  array([[59.84016393, 97.15983607],
#         [33.15983607, 53.84016393]]))

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_anova=df[["petal_width","species"]]

# %%
df_anova.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
grps=pd.unique(df_anova.species.values)
grps
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
d_data={grp:df_anova["petal_width"][df_anova.species==grp] for grp in grps}
d_data
# Out:
# {'setosa': 0     0.2
#  1     0.2
#  2     0.2
#  3     0.2
#  4     0.2
#  5     0.4
#  6     0.3
#  7     0.2
#  8     0.2
#  9     0.1
#  10    0.2
#  11    0.2
#  12    0.1
#  13    0.1
#  14    0.2
#  15    0.4
#  16    0.4
#  17    0.3
#  18    0.3
#  19    0.3
#  20    0.2
#  21    0.4
#  22    0.2
#  23    0.5
#  24    0.2
#  25    0.2
#  26    0.4
#  27    0.2
#  28    0.2
#  29    0.2
#  30    0.2
#  31    0.4
#  32    0.1
#  33    0.2
#  34    0.2
#  35    0.2
#  36    0.2
#  37    0.1
#  38    0.2
#  39    0.2
#  40    0.3
#  41    0.3
#  42    0.2
#  43    0.6
#  44    0.4
#  45    0.3
#  46    0.2
#  47    0.2
#  48    0.2
#  49    0.2
#  Name: petal_width, dtype: float64,
#  'versicolor': 50    1.4
#  51    1.5
#  52    1.5
#  53    1.3
#  54    1.5
#  55    1.3
#  56    1.6
#  57    1.0
#  58    1.3
#  59    1.4
#  60    1.0
#  61    1.5
#  62    1.0
#  63    1.4
#  64    1.3
#  65    1.4
#  66    1.5
#  67    1.0
#  68    1.5
#  69    1.1
#  70    1.8
#  71    1.3
# ...

# %%
f,p=scipy.stats.f_oneway(d_data["setosa"],d_data["versicolor"],d_data["versicolor"],d_data["virginica"])

# %%
print(round(p,4))
# Out:
# 0.0

# %%
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# reject null hypothesis

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a=df["species"].unique()
a
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data={i:df["petal_width"] for i in a}
pd.set_optiional
data
# Out:
# {'setosa': 0      0.2
#  1      0.2
#  2      0.2
#  3      0.2
#  4      0.2
#        ...
#  145    2.3
#  146    1.9
#  147    2.0
#  148    2.3
#  149    1.8
#  Name: petal_width, Length: 150, dtype: float64,
#  'versicolor': 0      0.2
#  1      0.2
#  2      0.2
#  3      0.2
#  4      0.2
#        ...
#  145    2.3
#  146    1.9
#  147    2.0
#  148    2.3
#  149    1.8
#  Name: petal_width, Length: 150, dtype: float64,
#  'virginica': 0      0.2
#  1      0.2
#  2      0.2
#  3      0.2
#  4      0.2
#        ...
#  145    2.3
#  146    1.9
#  147    2.0
#  148    2.3
#  149    1.8
#  Name: petal_width, Length: 150, dtype: float64}

# %%
f,p=scipy.stats.f_oneway(data["setosa"],data["versicolor"],data["versicolor"],data["virginica"])

# %%
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# accept null hypothesis
