# %% [markdown]
# # SEABORN

# %%
import seaborn as sns 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="darkgrid")

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x="total_bill",y="tip",data=df)

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day")

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day",size="sex")

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day",size="sex",style="time")

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="size",size="sex",style="time");

# %%
df1=pd.read_csv("C:\\Users\\Neeraj\\Downloads\\Advertising.csv")
df1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df1.sort_values("sales")
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 130         131    0.7   39.6        8.7    1.6
# 155         156    4.1   11.6        5.7    3.2
# 8             9    8.6    2.1        1.0    4.8
# 108         109   13.1    0.4       25.6    5.3
# 78           79    5.4   29.9        9.4    5.3
# ..          ...    ...    ...        ...    ...
# 98           99  289.7   42.3       51.2   25.4
# 147         148  243.2   49.0       44.3   25.4
# 198         199  283.6   42.0       66.2   25.5
# 183         184  287.6   43.0       71.8   26.2
# 175         176  276.9   48.9       41.8   27.0
#
# [200 rows x 5 columns]

# %%
df1.sort_values("radio")
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 127         128   80.2    0.0        9.2    8.8
# 107         108   90.4    0.3       23.2    8.7
# 108         109   13.1    0.4       25.6    5.3
# 117         118   76.4    0.8       14.8    9.4
# 157         158  149.8    1.3       24.3   10.1
# ..          ...    ...    ...        ...    ...
# 128         129  220.3   49.0        3.2   24.7
# 147         148  243.2   49.0       44.3   25.4
# 37           38   74.7   49.4       45.7   14.7
# 55           56  198.9   49.4       60.0   23.7
# 58           59  210.8   49.6       37.7   23.8
#
# [200 rows x 5 columns]

# %%
df1.sort_values("newspaper")
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 33           34  265.6   20.0        0.3   17.4
# 65           66   69.0    9.3        0.9    9.3
# 8             9    8.6    2.1        1.0    4.8
# 139         140  184.9   43.9        1.7   20.7
# 42           43  293.6   27.7        1.8   20.7
# ..          ...    ...    ...        ...    ...
# 118         119  125.7   36.9       79.2   15.9
# 165         166  234.5    3.4       84.8   11.9
# 75           76   16.9   43.7       89.4    8.7
# 101         102  296.4   36.3      100.9   23.8
# 16           17   67.8   36.6      114.0   12.5
#
# [200 rows x 5 columns]

# %%
sns.relplot(x="TV",y="sales",data=df1);

# %%
sns.relplot(x="radio",y="sales",data=df1);

# %%
sns.relplot(x="newspaper",y="sales",data=df1,hue="");

# %%
sns.pairplot(df1);

# %%
sns.barplot(x="day",y="tip",data=df);

# %%
sns.boxplot(x="day",y="tip",data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
df2=sns.load_dataset("fmri")
df2
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x="timepoint",y="signal",data=df2,ci=False);

# %%
sns.lineplot(x="timepoint",y="signal",data=df2,ci=False);

# %% [markdown]
# # 02--------------------------------------------------------------------------------------------------------

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="darkgrid")

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="time",col="sex")

# %% [markdown]
# # CATEGORICAL PLOT
# catplot(
# boxplot(
# stripplot(
# swarmplot(
# etc

# %%
sns.catplot(x="day",y="total_bill",data=df);

# %%
df.value_counts("day")
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# dtype: int64

# %%
sns.catplot(x="day",y="total_bill",data=df,jitter=False);

# %%
import warnings
warnings.filterwarnings("ignore")
sns.catplot(x="day",y="tip",data=df,kind="swarm",size=5);

# %%
sns.catplot(x="day",y="tip",data=df,kind="box",hue="sex")

# %%
dia=sns.load_dataset("diamonds")
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # 03--------------------------------------------------------------------------------------------------------

# %%
df=sns.load_dataset("tips")

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="violin",hue="sex");

# %%
g=sns.catplot(x="day",y="tip",data=df,kind="violin",inner=None)
sns.swarmplot(x="day",y="tip",color="k",data=df,ax=g.ax,size=3);

# %%
import warnings
warnings.filterwarnings("ignore")
sns.distplot(df["tip"]);

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="hex")

# %%
df=pd.read_csv("C:\\Users\\Neeraj\\Downloads\\Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
sns.regplot(x="sales",y="TV",data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='TV'>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
