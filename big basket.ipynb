# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # fetching data

# %%
df=pd.read_csv("C:\\Users\\Neeraj\\Desktop\\archive\\BigBasket Products.csv")
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# # basic information about the dataset

# %%
df.shape
# Out:
# (27555, 10)

# %%
df.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#              index    sale_price  market_price        rating
# count  27555.00000  27555.000000  27555.000000  18929.000000
# mean   13778.00000    322.514808    382.056664      3.943410
# std     7954.58767    486.263116    581.730717      0.739063
# min        1.00000      2.450000      3.000000      1.000000
# 25%     6889.50000     95.000000    100.000000      3.700000
# 50%    13778.00000    190.000000    220.000000      4.100000
# 75%    20666.50000    359.000000    425.000000      4.300000
# max    27555.00000  12500.000000  12500.000000      5.000000

# %%
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df=df.set_index("index")

# %% [markdown]
# # data cleaning

# %%
df.isna().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
df[df["product"].isna()]
# Out:
#       product   category sub_category          brand  sale_price  \
# index
# 14364     NaN  Beverages       Coffee  Cothas Coffee       200.0
#
#        market_price           type  rating  \
# index
# 14364         240.0  Ground Coffee     4.2
#
#                                              description
# index
# 14364  Cothas Specialty Blend Coffee and Chicory incl...

# %%
df["product"]=df["product"].fillna("Coffee")

# %%
df.isna().sum()
# Out:
# product            0
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
df[df["brand"].isna()]
# Out:
#                      product              category              sub_category  \
# index
# 9766   Food Package - Medium  Cleaning & Household  Disposables, Garbage Bag
#
#       brand  sale_price  market_price                       type  rating  \
# index
# 9766    NaN        50.0          50.0  Aluminium Foil, Clingwrap     NaN
#
#       description
# index
# 9766          NaN

# %%
df["rating"]=df["rating"].fillna(df["rating"].mean())

# %%
df["description"]=df["description"].fillna(df[df["description"].isna()]["type"])

# %%
df[df["brand"].isna()]
# Out:
#                      product              category              sub_category  \
# index
# 9766   Food Package - Medium  Cleaning & Household  Disposables, Garbage Bag
#
#       brand  sale_price  market_price                       type   rating  \
# index
# 9766    NaN        50.0          50.0  Aluminium Foil, Clingwrap  3.94341
#
#                      description
# index
# 9766   Aluminium Foil, Clingwrap

# %%
c=df[df["type"]=="Aluminium Foil, Clingwrap"]
c
# Out:
#                                     product              category  \
# index
# 2898                          Cooking Sheet  Cleaning & Household
# 2944        Silver Aluminium Foil Container  Cleaning & Household
# 3029        Silver Aluminium Foil 14 Micron  Cleaning & Household
# 3161                 Greener - Sandwich Bag  Cleaning & Household
# 5584          Aluminium Foil - 10.5 Microns  Cleaning & Household
# 7403   Freshwrapp - Standard Aluminium Foil  Cleaning & Household
# 7586       Uniwrap Food Wrapping Paper - 11  Cleaning & Household
# 8198            Aluminium Foil - 18 Microns  Cleaning & Household
# 9766                  Food Package - Medium  Cleaning & Household
# 11625         Aluminium Container - Regular  Cleaning & Household
# 13153           Aluminium Foil - 18 Microns  Cleaning & Household
# 14085                Foil Container - Small  Cleaning & Household
# 14417         Aluminium Foil - 10.5 Microns  Cleaning & Household
# ...

# %%
df["brand"]=df["brand"].fillna(c["brand"].mode()[0])

# %%
df.isna().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
df[(df["category"]=="Cleaning & Household") & (df["product"]=="Food Package - Medium")]
# Out:
#                      product              category              sub_category  \
# index
# 9766   Food Package - Medium  Cleaning & Household  Disposables, Garbage Bag
#
#       brand  sale_price  market_price                       type   rating  \
# index
# 9766   Glad        50.0          50.0  Aluminium Foil, Clingwrap  3.94341
#
#                      description
# index
# 9766   Aluminium Foil, Clingwrap

# %%
len(df["product"].value_counts())             # no. of products in big basket
# Out:
# 23541

# %%
df["product"].value_counts()                 # how many brandtypes we have according to product
# Out:
# Turmeric Powder/Arisina Pudi                                     26
# Extra Virgin Olive Oil                                           15
# Cow Ghee/Tuppa                                                   14
# Soft Drink                                                       12
# Colorsilk Hair Colour With Keratin                               12
#                                                                  ..
# Sauteed Onion & Garlic Pasta Sauce                                1
# Pepper & Herb Salami Chicken                                      1
# Nutmeg Powder                                                     1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude     1
# Green Tea - Pure Original                                         1
# Name: product, Length: 23541, dtype: int64

# %%
df["category"].value_counts()           #how many categories we have and their types
# Out:
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: category, dtype: int64

# %%
df["type"].value_counts()          #no of products according to type
# Out:
# Face Care                1508
# Ayurveda                  538
# Men's Deodorants          500
# Shampoo & Conditioner     461
# Glassware                 415
#                          ...
# Bagels & Baguette           1
# Roses                       1
# Marinated Meat              1
# Organic Eggs                1
# Turkey & Duck               1
# Name: type, Length: 426, dtype: int64

# %%
df["brand"].value_counts()    #no. of products according to brand
# Out:
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Wellastrate           1
# Clean & Fresh         1
# Lal                   1
# Glint                 1
# Baron De Bercy        1
# Name: brand, Length: 2313, dtype: int64

# %%
df.groupby(["category"])["brand"].value_counts()   #which brands we have according to category
# Out:
# category                brand
# Baby Care               Huggies          67
#                         Pampers          63
#                         Mee Mee          41
#                         Himalaya         33
#                         The Moms Co      32
#                                          ..
# Snacks & Branded Foods  Vinanth           1
#                         Woh Hup           1
#                         Wow Chocolina     1
#                         bb Popular        1
#                         iD                1
# Name: brand, Length: 2780, dtype: int64

# %%
df.groupby("category")["sale_price"].agg(["max","min"])  #what maximum & minimum cost of items we have accoring to category
# Out:
#                                max    min
# category
# Baby Care                  3299.00  15.00
# Bakery, Cakes & Dairy      1108.00   5.00
# Beauty & Hygiene           8184.44   3.00
# Beverages                  3480.00   9.00
# Cleaning & Household       3600.00   5.00
# Eggs, Meat & Fish          2249.10  42.50
# Foodgrains, Oil & Masala   4099.00   9.50
# Fruits & Vegetables         527.00   2.45
# Gourmet & World Food       7299.00   5.00
# Kitchen, Garden & Pets    12500.00  17.00
# Snacks & Branded Foods     1950.00   5.00

# %%
sns.set(style="darkgrid")

# %%
x=df["sale_price"].mean()          #average sale price of big basket
x
# Out:
# 322.51480783886655

# %%
y=df["market_price"].mean()        #average market price 
y
# Out:
# 382.05666448920334

# %%
p=(x/y)*100                       # therefore price of big basket is 15.58% less than the market
round(100-p,2)
# Out:
# 15.58

# %%
plt.figure(figsize=(7,7))

ndf=pd.DataFrame({"s":["sale_price","market_price"],"m":[322.51,382.05]})   #sale price vs market price
plt.bar(ndf["s"],ndf["m"]);

# %%
df["rating"].sort_values
# Out:
# <bound method Series.sort_values of index
# 1        4.1
# 2        2.3
# 3        3.4
# 4        3.7
# 5        4.4
#         ...
# 27551    3.9
# 27552    4.0
# 27553    3.8
# 27554    4.2
# 27555    4.5
# Name: rating, Length: 27555, dtype: float64>

# %%
df["rating"].unique()
# Out:
# array([4.1       , 2.3       , 3.4       , 3.7       , 4.4       ,
#        3.3       , 3.6       , 4.        , 3.5       , 4.3       ,
#        2.2       , 5.        , 3.8       , 4.2       , 4.9       ,
#        3.9       , 1.5       , 2.9       , 2.6       , 3.        ,
#        4.5       , 3.94340958, 1.        , 4.6       , 4.8       ,
#        3.1       , 2.        , 1.8       , 2.8       , 3.2       ,
#        4.7       , 2.5       , 2.4       , 2.7       , 2.1       ,
#        1.7       , 1.9       , 1.2       , 1.3       , 1.4       ,
#        1.6       ])

# %%
df[df["rating"]==5.0]                        #highest rated products
# Out:
#                                        product                  category  \
# index
# 13             Face Wash - Oil Control, Active          Beauty & Hygiene
# 17              Smooth Skin Oil - For Dry Skin          Beauty & Hygiene
# 25                               Veggie Cutter    Kitchen, Garden & Pets
# 45                          Plain Green Olives      Gourmet & World Food
# 93                      Topp Up Milk - Elaichi     Bakery, Cakes & Dairy
# ...                                        ...                       ...
# 27508                   Extra Crisp Sweet Corn      Gourmet & World Food
# 27509              Palm Jaggery/Bella Crystals  Foodgrains, Oil & Masala
# 27513  Water Bottle - Fridge, Tulip, Dark Blue    Kitchen, Garden & Pets
# 27516                 EDT Spray - Musk For Men          Beauty & Hygiene
# 27549              Apple Cider Vinegar Shampoo          Beauty & Hygiene
#
#                   sub_category              brand  sale_price  market_price  \
# ...

# %%
df[df["rating"]==1.0]                           #lowest rated products
# Out:
#                                                  product  \
# index
# 65                    Aqua Halo Rejuvenating Conditioner
# 299                       Family Sunscreen Lotion SPF 25
# 300                           Japanese Cooking Rice-Wine
# 436    Aloe Vera Juice - Purifies Blood & Boosts Immu...
# 452                           Hair Serum - Anti-Dandruff
# ...                                                  ...
# 27192  Mukhallat Khas Concentrated Oriental Perfume F...
# 27263                                  PP Raspberry Belt
# 27286  Dry Shampoo - Instant Hair Refresh, Coconut & ...
# 27368  Moroccan Argan Hair Growth Oil For Hair Growth...
# 27519           Gluten-Free Vegetable Millet Khichdi Mix
#
#                    category            sub_category            brand  \
# index
# 65         Beauty & Hygiene               Hair Care          Azafran
# 299        Beauty & Hygiene               Skin Care          INATUR
# ...

# %%
n=df.sort_values("rating")                #highest rating 5 products
n.tail()
# Out:
#                                                  product  \
# index
# 24431                       Fields of Gold - Basil Seeds
# 8835         Bruschetta Tomato Topping For Grilled Bread
# 18750                           Lemongrass Floor Cleaner
# 9250                              Total Effects - SPF 15
# 11926  Della Storage Container With Lid - Assorted Co...
#
#                        category            sub_category      brand  \
# index
# 24431  Foodgrains, Oil & Masala        Masalas & Spices   PRISTINE
# 8835       Gourmet & World Food  Sauces, Spreads & Dips  Montanini
# 18750      Cleaning & Household    All Purpose Cleaners     Nimyle
# 9250           Beauty & Hygiene               Skin Care       Olay
# 11926      Cleaning & Household    Bins & Bathroom Ware     Nakoda
#
#        sale_price  market_price                      type  rating  \
# index
# 24431       92.15          95.0         Herbs & Seasoning     5.0
# ...

# %%
n.head()                               #lowest rating 5 products
# Out:
#                                                  product  \
# index
# 5910                   Face and Body Mist - Frankincense
# 17285                             Soap Case - Avenue Nxt
# 26309             Ceramic Barrel Brush - Colour May Vary
# 4658               Black Gram Lentils Curry-Basmati Rice
# 10617  3mm Hard Aluminium Anodized Fry Pan - Inductio...
#
#                      category          sub_category                 brand  \
# index
# 5910         Beauty & Hygiene             Skin Care         ORGANIC INDIA
# 17285        Beauty & Hygiene      Bath & Hand Wash          Plasto World
# 26309        Beauty & Hygiene             Hair Care  Bronson Professional
# 4658   Snacks & Branded Foods   Ready To Cook & Eat         Fazlani Foods
# 10617  Kitchen, Garden & Pets  Cookware & Non Stick                 HAZEL
#
#        sale_price  market_price                    type  rating  \
# index
# 5910        325.0         325.0               Body Care     1.0
# ...

# %%
plt.figure(figsize=(7,7))                             #which category we have more in big basket


plt.pie([7867,4690,3580,2814,2676,2675,885,851,610,557,350],labels=["Beauty & Hygiene","Gourmet & World Food","Kitchen Garden & Pets","Snacks & Branded Foods","Foodgrains Oil & Masala","Cleaning & Household","Beverages","Bakery Cakes & Dairy","Baby Care","Fruits & Vegetables","Eggs Meat & Fish"]);
