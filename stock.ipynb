# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import pylab
import scipy.stats as st

# %%
df=pd.read_excel("C:\\Users\\Neeraj\\Downloads\\Data Analytics  -Indian Stock Market Top 2000.xlsx",header=1)
df
# Out:
#                                Name     Ticker  \
# 0           Reliance Industries Ltd   RELIANCE
# 1     Tata Consultancy Services Ltd        TCS
# 2                     HDFC Bank Ltd   HDFCBANK
# 3                       Infosys Ltd       INFY
# 4                    ICICI Bank Ltd  ICICIBANK
# ...                             ...        ...
# 1995            Galaxy Bearings Ltd    GALXBRG
# 1996          Signet Industries Ltd     SIGIND
# 1997                      Suraj Ltd   SURAJLTD
# 1998                     Polson Ltd     POLSON
# 1999                LKP Finance Ltd     LKPFIN
#
#                             Sub-Sector    Market Cap  Close Price   PE Ratio  \
# 0     Oil & Gas - Refining & Marketing  1.679534e+06      2467.40  34.186904
# 1             IT Services & Consulting  1.358569e+06      3626.70  41.892356
# 2                        Private Banks  8.206363e+05      1486.50  25.779258
# 3             IT Services & Consulting  7.775010e+05      1853.05  40.178853
# ...

# %%
display("Close Price")
# Out:
# 'Close Price'

# %%
df.columns
# Out:
# Index(['Name', 'Ticker', 'Sub-Sector', 'Market Cap', 'Close Price', 'PE Ratio',
#        'Return on Equity', 'Return on Assets', 'Net Profit Margin',
#        '5Y Avg EBITDA Margin', 'EBITDA Margin', '1Y Return vs Nifty',
#        '5Y CAGR', 'Debt to Equity', 'Long Term Debt to Equity',
#        'Net Income / Liabilities', '5Y Historical Revenue Growth',
#        '5Y Historical EBITDA Growth', '5Y Hist Op. Cash Flow Growth',
#        '5Y Historical EPS Growth', 'Forward PE Ratio', 'Enterprise Value',
#        'PB Ratio', 'Dividend Yield', 'PE Premium vs Sector',
#        'Domestic Institutional Holding', 'Mutual Fund Holding',
#        'Promoter Holding', 'Foreign Institutional Holding',
#        'Retail Investor Holding', 'Pledged Promoter Holdings',
#        'Insurance Firms Holding', 'No. of Shareholders', 'Total Revenue',
#        'Net Income', 'PBT', 'Earnings Per Share', 'EBITDA',
#        'Long Term Investments', 'Reserves & Surplus', 'Cash and Equivalent',
# ...

# %%
df.shape
# Out:
# (2000, 44)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Name                            2000 non-null   object
#  1   Ticker                          2000 non-null   object
#  2   Sub-Sector                      1947 non-null   object
#  3   Market Cap                      2000 non-null   float64
#  4   Close Price                     2000 non-null   float64
#  5   PE Ratio                        1957 non-null   float64
#  6   Return on Equity                1870 non-null   object
#  7   Return on Assets                1952 non-null   object
#  8   Net Profit Margin               1953 non-null   float64
#  9   5Y Avg EBITDA Margin            1880 non-null   float64
#  10  EBITDA Margin                   1953 non-null   object
#  11  1Y Return vs Nifty              2000 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Market Cap   Close Price      PE Ratio  Net Profit Margin  \
# count  2.000000e+03   2000.000000  1.957000e+03       1.953000e+03
# mean   1.316900e+04    740.793690  4.560860e+13      -6.268385e+02
# std    6.659485e+04   2498.262371  2.017633e+15       2.653735e+04
# min    1.249950e+02      0.200000 -6.046040e+03      -1.172500e+06
# 25%    3.116762e+02     80.862500  7.035122e+00       9.725617e-01
# 50%    1.039122e+03    221.150000  2.102286e+01       5.788951e+00
# 75%    5.041667e+03    609.062500  4.920941e+01       1.251864e+01
# max    1.679534e+06  66876.350000  8.925604e+16       2.443590e+03
#
#        5Y Avg EBITDA Margin  1Y Return vs Nifty      5Y CAGR  Debt to Equity  \
# count           1880.000000         2000.000000  1593.000000     1835.000000
# mean            -234.927295          110.163582    14.428792      138.629604
# std             9542.274154          573.152064    29.226935     1361.068722
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Firstly, screen the companies and visualise them according to sub-sectors using a pie chart or a bar charts.

# %%
df["Sub-Sector"].value_counts()[:7]
# Out:
# Pharmaceuticals         104
# Textiles                 86
# Auto Parts               84
# Industrial Machinery     76
# Commodity Chemicals      73
# Iron & Steel             71
# Real Estate              67
# Name: Sub-Sector, dtype: int64

# %%
a=["Pharmaceuticals","Textiles","Auto Parts","Industrial Machinery","Commodity Chemicals","Iron & Steel"]
b=[104,86,84,76,73,71]
plt.pie(b,labels=a,radius=2,autopct="%0.1f%%");

# %% [markdown]
# # Secondly, visualise the companies by segregating them according to Market Cap inhree categories: Large Cap(>20,000 crore), Mid Cap (5,000 to 20,000 crore) &Small Cap(<5,000).

# %%
large_cap=df[df["Market Cap"]>=20000]
large_cap
# Out:
#                                 Name      Ticker  \
# 0            Reliance Industries Ltd    RELIANCE
# 1      Tata Consultancy Services Ltd         TCS
# 2                      HDFC Bank Ltd    HDFCBANK
# 3                        Infosys Ltd        INFY
# 4                     ICICI Bank Ltd   ICICIBANK
# ..                               ...         ...
# 220                       Pfizer Ltd      PFIZER
# 221          LIC Housing Finance Ltd   LICHSGFIN
# 222            Bayer Cropscience Ltd   BAYERCROP
# 223  New India Assurance Company Ltd       NIACL
# 224              Vinati Organics Ltd  VINATIORGA
#
#                            Sub-Sector    Market Cap  Close Price   PE Ratio  \
# 0    Oil & Gas - Refining & Marketing  1.679534e+06      2467.40  34.186904
# 1            IT Services & Consulting  1.358569e+06      3626.70  41.892356
# 2                       Private Banks  8.206363e+05      1486.50  25.779258
# ...

# %%
mid_cap=df[(df["Market Cap"]<20000) & (df["Market Cap"]>=5000)]
mid_cap
# Out:
#                                 Name      Ticker  \
# 225       Indian Energy Exchange Ltd         IEX
# 226                         CPSE ETF     CPSEETF
# 227              Tanla Platforms Ltd       TANLA
# 228                Bank of India Ltd   BANKINDIA
# 229             Aavas Financiers Ltd       AAVAS
# ..                               ...         ...
# 501                        Hikal Ltd       HIKAL
# 502       Indiabulls Real Estate Ltd   IBREALEST
# 503  Barbeque-Nation Hospitality Ltd    BARBEQUE
# 504              Sharda Cropchem Ltd  SHARDACROP
# 505     Lloyds Metals And Energy Ltd    LLOYDSME
#
#                        Sub-Sector    Market Cap  Close Price      PE Ratio  \
# 225   Power Trading & Consultancy  19991.433286       220.95     97.003413
# 226                        Equity  19984.546496        33.23           NaN
# 227             Software Services  19899.614944      1464.75     55.877390
# ...

# %%
small_cap=df[df["Market Cap"]<5000]
small_cap
# Out:
#                                    Name      Ticker  \
# 506    Edelweiss Financial Services Ltd   EDELWEISS
# 507   Mahindra Lifespace Developers Ltd     MAHLIFE
# 508                TCNS Clothing Co Ltd  TCNSBRANDS
# 509                             HEG Ltd         HEG
# 510                    Rallis India Ltd      RALLIS
# ...                                 ...         ...
# 1995                Galaxy Bearings Ltd     GALXBRG
# 1996              Signet Industries Ltd      SIGIND
# 1997                          Suraj Ltd    SURAJLTD
# 1998                         Polson Ltd      POLSON
# 1999                    LKP Finance Ltd      LKPFIN
#
#                               Sub-Sector   Market Cap  Close Price  \
# 506               Diversified Financials  4940.092768        55.50
# 507                          Real Estate  4917.349619       319.55
# 508                Apparel & Accessories  4897.591456       791.35
# ...

# %%
df
# Out:
#                                Name     Ticker  \
# 0           Reliance Industries Ltd   RELIANCE
# 1     Tata Consultancy Services Ltd        TCS
# 2                     HDFC Bank Ltd   HDFCBANK
# 3                       Infosys Ltd       INFY
# 4                    ICICI Bank Ltd  ICICIBANK
# ...                             ...        ...
# 1995            Galaxy Bearings Ltd    GALXBRG
# 1996          Signet Industries Ltd     SIGIND
# 1997                      Suraj Ltd   SURAJLTD
# 1998                     Polson Ltd     POLSON
# 1999                LKP Finance Ltd     LKPFIN
#
#                             Sub-Sector    Market Cap  Close Price   PE Ratio  \
# 0     Oil & Gas - Refining & Marketing  1.679534e+06      2467.40  34.186904
# 1             IT Services & Consulting  1.358569e+06      3626.70  41.892356
# 2                        Private Banks  8.206363e+05      1486.50  25.779258
# 3             IT Services & Consulting  7.775010e+05      1853.05  40.178853
# ...

# %%
df[df["Net Profit Margin"]==2443.58974358974]
# Out:
#                  Name      Ticker           Sub-Sector  Market Cap  \
# 1050  Hexa Tradex Ltd  HEXATRADEX  Commodities Trading  918.443204
#
#       Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 1050        160.0  96.373893  1.31111906006659  1.09457193393518
#
#       Net Profit Margin  5Y Avg EBITDA Margin  ... Net Income    PBT  \
# 1050        2443.589744          -2043.407992  ...       9.53  10.01
#
#       Earnings Per Share  EBITDA  Long Term Investments  Reserves & Surplus  \
# 1050    1.72503193662222   10.28                1488.86             1007.42
#
#       Cash and Equivalent  Book Value  Free Cash Flow  Operating Cash Flow
# 1050                  0.1     1215.44           -2.26                -2.25
#
# [1 rows x 44 columns]

# %%
df["Sub-Sector"].value_counts()
# Out:
# Pharmaceuticals           104
# Textiles                   86
# Auto Parts                 84
# Industrial Machinery       76
# Commodity Chemicals        73
#                          ...
# Mining - Copper             1
# Payment Infrastructure      1
# Mining - Iron Ore           1
# Soft Drinks                 1
# Metals - Iron               1
# Name: Sub-Sector, Length: 137, dtype: int64

# %%
df1=df[df["Sub-Sector"]=="Pharmaceuticals"]
df1["Net Profit Margin"].mean()
# Out:
# 10.635780863193538

# %%
df2=df[df["Sub-Sector"]=="Textiles"]
df2["Net Profit Margin"].mean()
# Out:
# 3.266355709031362

# %%
df3=df[df["Sub-Sector"]=="Auto Parts"]
df3["Net Profit Margin"].mean()
# Out:
# 3.6793739196443105

# %%
df4=df[df["Sub-Sector"]=="Soft Drinks"]
df4
# Out:
#                     Name Ticker   Sub-Sector    Market Cap  Close Price  \
# 116  Varun Beverages Ltd    VBL  Soft Drinks  41090.508961        943.3
#
#       PE Ratio  Return on Equity  Return on Assets  Net Profit Margin  \
# 116  59.203108  17.8295778428847  7.70029578117963            7.50888
#
#      5Y Avg EBITDA Margin  ...        Net Income      PBT  Earnings Per Share  \
# 116             18.094261  ...  694.060000000001  1006.61           16.027875
#
#       EBITDA  Long Term Investments  Reserves & Surplus  Cash and Equivalent  \
# 116  1744.84                    0.0             1173.41               336.62
#
#      Book Value  Free Cash Flow  Operating Cash Flow
# 116      4196.7          396.62              1231.42
#
# [1 rows x 44 columns]

# %%
for i in df["Sub-Sector"].unique():
    sns.()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10312/3722281069.py in <module>
#       1 for i in df["Sub-Sector"].unique():
# ----> 2     sns.countplot(i)
#       3
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
#    3600         estimator, ci, n_boot, units, seed,
#
# ...
